# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.12)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 6.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 6.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.3.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
import pandas as pd
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df[(df['job_title_short']=='Data Analyst') & (df['salary_year_avg']>100_000)][['job_location','job_title','salary_year_avg']].iloc[0:100]
# Out:
#              job_location                                      job_title  \
# 410    Atlantic Beach, FL    IT Business Lead Data Analyst - VP - Hybrid
# 1555     Aveiro, Portugal                  Data Analyst/Engineer (M/F/D)
# 1681           Irvine, CA                                   Data Analyst
# 1684            Tampa, FL                       Data Analyst - Data17829
# 1867          Chicago, IL  Data Integration Analyst (West Coast/Chicago)
# ...                   ...                                            ...
# 30808       Rockville, MD              Food Security Survey Data Analyst
# 31002        New York, NY           Institutional Data/Reporting Analyst
# 31148        Bethesda, MD                               Data Analyst SME
# 31152       Palo Alto, CA                      Applied Scientist, Search
# 32032         Atlanta, GA                                   Data Analyst
#
#        salary_year_avg
# 410           133285.0
# 1555          111175.0
# 1681          111175.0
# 1684          120000.0
# 1867          101500.0
# ...                ...
# 30808         115000.0
# 31002         115000.0
# 31148         115000.0
# 31152         179000.0
# 32032         117500.0
#
# [100 rows x 3 columns]

# %%
#df[(df['job_title_short']=='Data Analyst') & (df['salary_year_avg']>100_000)]
df[(df['job_title_short']=='Data Analyst') & (df['salary_year_avg'].notna())][['job_location','job_title','salary_year_avg']][0:10]
# Out:
#             job_location                                    job_title  \
# 109             Anywhere        Senior Supply Chain Analytics Analyst
# 180        Dos Palos, CA                             Data Analyst III
# 410   Atlantic Beach, FL  IT Business Lead Data Analyst - VP - Hybrid
# 988      Springfield, MA                        DATA ANALYST (ONSITE)
# 1413         Atlanta, GA                          Junior BI Developer
# 1490              Poland                              HR Data Analyst
# 1555    Aveiro, Portugal                Data Analyst/Engineer (M/F/D)
# 1587      Long Beach, CA                              Sr Data Analyst
# 1681          Irvine, CA                                 Data Analyst
# 1684           Tampa, FL                     Data Analyst - Data17829
#
#       salary_year_avg
# 109          89000.00
# 180          90250.00
# 410         133285.00
# 988          62623.00
# 1413         71300.00
# 1490         43200.00
# 1555        111175.00
# 1587         89111.75
# 1681        111175.00
# 1684        120000.00

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df.drop(labels='job_posted_month',axis=1,inplace=True)

# %%
df.sort_values(by='job_posted_date', inplace=True)

# %%
df.drop(labels='salary_hour_avg',axis=1,inplace=True)

# %%
df.dropna(axis=0, how='any', subset=['salary_year_avg'],inplace=True)

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860247552    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
dfm = df.groupby(by='job_title_short')[['salary_year_avg']].agg(['min','mean','median','max'])

# %%
dfm.columns
# Out:
# Index([   ('salary_year_avg', 'min'),   ('salary_year_avg', 'mean'),
#        ('salary_year_avg', 'median'),    ('salary_year_avg', 'max')],
#       dtype='object')

# %%
dfm.columns = dfm.columns.to_flat_index()

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Business Analyst to Software Engineer
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   (salary_year_avg, min)     10 non-null     float64
#  1   (salary_year_avg, mean)    10 non-null     float64
#  2   (salary_year_avg, median)  10 non-null     float64
#  3   (salary_year_avg, max)     10 non-null     float64
# dtypes: float64(4)
# memory usage: 400.0+ bytes

# %%
dfm.columns=[f'{j}' if j != '' else f'{i}' for i,j in dfm.columns]

# %%
dfm
# Out:
#                            (salary_year_avg, min)  (salary_year_avg, mean)  \
# job_title_short
# Business Analyst                          16500.0             91082.612833
# Cloud Engineer                            42000.0            111268.453846
# Data Analyst                              25000.0             93841.907854
# Data Engineer                             15000.0            130125.604250
# Data Scientist                            27000.0            135988.837171
# Machine Learning Engineer                 30000.0            126774.315972
# Senior Data Analyst                       30000.0            113911.363665
# Senior Data Engineer                      35000.0            145840.611624
# Senior Data Scientist                     45000.0            154206.292996
# Software Engineer                         28000.0            113393.760054
#
#                            (salary_year_avg, median)  (salary_year_avg, max)
# job_title_short
# Business Analyst                             85000.0                387460.0
# Cloud Engineer                               90000.0                280000.0
# Data Analyst                                 90000.0                650000.0
# Data Engineer                               125000.0                525000.0
# Data Scientist                              127500.0                960000.0
# Machine Learning Engineer                   106415.0                325000.0
# Senior Data Analyst                         111175.0                425000.0
# Senior Data Engineer                        147500.0                425000.0
# Senior Data Scientist                       155500.0                890000.0
# Software Engineer                            99150.0                375000.0

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
datetime_counts = df.job_posted_date.value_counts().sort_index()

# %%
plt.plot(datetime_counts.index,datetime_counts)
plt.show()

# %%
date_counts = df.job_posted_date.groupby(by=df.job_posted_date.dt.date).count().sort_index()
#us_jobs.groupby(by=['job_title_short'])[['salary_year_avg']].min()

# %%
date_counts
# Out:
# job_posted_date
# 2023-01-01    3603
# 2023-01-02    2772
# 2023-01-03    2565
# 2023-01-04    3937
# 2023-01-05    3297
#               ...
# 2023-12-27    1834
# 2023-12-28    1767
# 2023-12-29    1107
# 2023-12-30     897
# 2023-12-31     758
# Name: job_posted_date, Length: 365, dtype: int64

# %%
plt.plot(date_counts.index,date_counts)
plt.show()

# %%
month_counts = df.job_posted_date.groupby(by=df.job_posted_date.dt.month).count().sort_index()
month_counts
# Out:
# job_posted_date
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: job_posted_date, dtype: int64

# %%
plt.plot(month_counts.index,month_counts.values)
plt.show()

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
month_counts = df.groupby(by=df.job_posted_month)['job_posted_month'].count().sort_index()
month_counts
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: job_posted_month, dtype: int64

# %%
month_counts = df['job_posted_month'].value_counts().sort_index()
month_counts
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
job_counts = df.job_title_short.value_counts()

# %%
job_counts
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
job_counts_asc=job_counts.sort_values(ascending=True)

# %%
plt.barh(job_counts_asc.index,job_counts_asc)
plt.show()

# %%
plt.bar(job_counts.index,job_counts.values)
plt.title("Postings by Job Title")
plt.ylabel("Number of Job Postings")
plt.xlabel("Job Title")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
job_counts.plot(kind='bar')
plt.title("Postings by Job Title")
plt.ylabel("Number of Job Postings")
plt.xlabel("Job Title")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
df.plot(x='job_posted_date',y='salary_year_avg',kind='line')
# Out:
# <Axes: xlabel='job_posted_date'>

# %%
jpm = df.groupby(by=df.job_posted_month)[['job_posted_month','salary_year_avg']].mean()
jpm['job_posted_month'] =jpm['job_posted_month'].fillna(0).astype(int)

# %%
jpm['job_posted_month'] =jpm['job_posted_month'].fillna(0).astype(int)

# %%
jpm.head()
# Out:
#                   job_posted_month  salary_year_avg
# job_posted_month
# 1                                1    123007.422072
# 2                                2    122913.927237
# 3                                3    122947.810047
# 4                                4    121856.551050
# 5                                5    123656.747729

# %%
jpm.plot(x='job_posted_month',y='salary_year_avg',kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
job_salary = df.groupby(by='job_title_short')['salary_year_avg'].median().sort_values()

# %%
job_salary.plot(kind='barh')
plt.title("Median Salary by Job Title")
plt.ylabel("")
plt.xlabel("Salary ($USD)")
plt.show()
